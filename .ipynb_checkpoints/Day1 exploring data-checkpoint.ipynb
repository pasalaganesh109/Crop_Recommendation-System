# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (1.26.2)
# [notice] A new release of pip available: 22.2.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# [notice] A new release of pip available: 22.2.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (3.8.2)
# [notice] A new release of pip available: 22.2.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pillow>=8 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from matplotlib) (4.46.0)
# Requirement already satisfied: six>=1.5 in c:\users\pasal\onedrive\desktop\codegnan\pasala\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Crop_recommendation.csv')
data
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label  Unnamed: 8  Unnamed: 9
# 0     202.935536    rice         NaN         NaN
# 1     226.655537    rice         NaN         NaN
# 2     263.964248    rice         NaN         NaN
# 3     242.864034    rice         NaN         NaN
# 4     262.717340    rice         NaN         NaN
# ...          ...     ...         ...         ...
# 2195  177.774507  coffee         NaN         NaN
# 2196  127.924610  coffee         NaN         NaN
# 2197  173.322839  coffee         NaN         NaN
# 2198  127.175293  coffee         NaN         NaN
# 2199  140.937041  coffee         NaN         NaN
#
# [2200 rows x 10 columns]

# %%
data.columns
# Out:
# Index(['Nitrogen', 'phosphorus', 'potassium', 'temperature', 'humidity', 'ph',
#        'rainfall', 'label', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
#data.info()

# %%
data.head()
# Out:
#    Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
#
#      rainfall label  Unnamed: 8  Unnamed: 9
# 0  202.935536  rice         NaN         NaN
# 1  226.655537  rice         NaN         NaN
# 2  263.964248  rice         NaN         NaN
# 3  242.864034  rice         NaN         NaN
# 4  262.717340  rice         NaN         NaN

# %%
data.drop(columns=['Unnamed: 8','Unnamed: 9'],inplace=True)

# %%
#data

# %%
data.shape
# Out:
# (2200, 8)

# %%
data.isnull().sum()
# Out:
# Nitrogen       0
# phosphorus     0
# potassium      0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#           Nitrogen   phosphorus    potassium  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
data
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label
# 0     202.935536    rice
# 1     226.655537    rice
# 2     263.964248    rice
# 3     242.864034    rice
# 4     262.717340    rice
# ...          ...     ...
# 2195  177.774507  coffee
# 2196  127.924610  coffee
# 2197  173.322839  coffee
# 2198  127.175293  coffee
# 2199  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
#we use sklearn for feature encoding
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[89], line 2
#       1 #we use sklearn for feature encoding
# ----> 2 from sklearn.preprocessing import LabelEncoder
#       3 label=LabelEncoder()
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
data['Type'] = label.fit_transform(data['Type'])
encoded_to_original=dict(zip(label.transform(label.classes_),
                            label.classes_))
for encoded_label,original_value in encoded_to_original.items():
  print(f'{encoded_label}={original_value}')

# %%
corr=data.drop(columns=['label']).corr()
corr
# Out:
#              Nitrogen  phosphorus  potassium  temperature  humidity        ph  \
# Nitrogen     1.000000   -0.231460  -0.140512     0.026504  0.190688  0.096683
# phosphorus  -0.231460    1.000000   0.736232    -0.127541 -0.118734 -0.138019
# potassium   -0.140512    0.736232   1.000000    -0.160387  0.190859 -0.169503
# temperature  0.026504   -0.127541  -0.160387     1.000000  0.205320 -0.017795
# humidity     0.190688   -0.118734   0.190859     0.205320  1.000000 -0.008483
# ph           0.096683   -0.138019  -0.169503    -0.017795 -0.008483  1.000000
# rainfall     0.059020   -0.063839  -0.053461    -0.030084  0.094423 -0.109069
#
#              rainfall
# Nitrogen     0.059020
# phosphorus  -0.063839
# potassium   -0.053461
# temperature -0.030084
# humidity     0.094423
# ph          -0.109069
# rainfall     1.000000

# %%
# !pip install seaborn
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
sns.heatmap(corr,annot=True,cbar=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
data['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
sns.distplot(data['N'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\codegnan\pasala\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'N'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 sns.distplot(data['N'])
#       3 plt.show()
#
# File ~\OneDrive\Desktop\codegnan\pasala\lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\OneDrive\Desktop\codegnan\pasala\lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'N'
